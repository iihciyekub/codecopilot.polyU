# %%
import pickle

# Open the file 'reslist.pickle' in the local directory using pickle library
with open('reslist.pickle', 'rb') as f:
    reslist = pickle.load(f)

reslist

# %%
reslist[0][2]
# Out:
#       Details for Case No. 4210987
# 0                        Defendant  \
# 1                      Description
# 2                              NaN
# 3                     Offence Date
# 4                       Total Fine
# 5   Breaches involved in this Case
# 6              Location of Offence
# 7                          Address
# 8                          Address
# 9                          Address
# 10                         Address
# 11                         Address
# 12                     HSE Details
# 13                       HSE Group
# 14                        HSE Area
#
#                        Details for Case No. 4210987.1
# 0                       Direct Plant Services Limited  \
# 1                                                 NaN
# 2   This case did result from the investigation of...
# 3                                          01/01/2005
# 4                                         £100,000.00
# 5                      Breaches involved in this Case
# 6                                 Location of Offence
# 7             Roadway Mill Lane Box Wiltshire England
# 8             Roadway Mill Lane Box Wiltshire England
# 9             Roadway Mill Lane Box Wiltshire England
# 10            Roadway Mill Lane Box Wiltshire England
# 11            Roadway Mill Lane Box Wiltshire England
# 12                                        HSE Details
# 13                                         CDOP3GRP14
# 14                                                NaN
#
#                        Details for Case No. 4210987.2
# 0                       Direct Plant Services Limited  \
# 1                                                 NaN
# 2   This case did result from the investigation of...
# 3                                          01/01/2005
# 4                          Total Costs Awarded to HSE
# 5                      Breaches involved in this Case
# 6                                 Location of Offence
# 7                                              Region
# 8                                     Local Authority
# 9                                            Industry
# 10                                      Main Activity
# 11                                   Type of Location
# 12                                        HSE Details
# 13                                    HSE Directorate
# 14                                       HSE Division
#
#                        Details for Case No. 4210987.3
# 0                       Direct Plant Services Limited
# 1                                                 NaN
# 2   This case did result from the investigation of...
# 3                                          01/01/2005
# 4                                          £56,890.78
# 5                      Breaches involved in this Case
# 6                                 Location of Offence
# 7                                  Wales & South West
# 8                                        Wiltshire UA
# 9                                        Construction
# 10             43999 - SPECIALISED CONST NOT SCAFFOLD
# 11                                                NaN
# 12                                        HSE Details
# 13                       Field Operations Directorate
# 14                                         South West
